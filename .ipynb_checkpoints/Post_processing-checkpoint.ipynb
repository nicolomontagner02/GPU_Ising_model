# %%
import matplotlib.pyplot as plt
import numpy as np
import sys

# %% [markdown]
# ## Plot 2D heatmap

# %%
def plot_lattice(filename):
    lattice = np.loadtxt(filename)

    plt.figure(figsize=(6, 6))
    plt.imshow(lattice,
               cmap="cool",
               origin="lower",
               vmin=-1,
               vmax=1)
    plt.colorbar(label="Spin value")
    plt.title("2D Ising Lattice")
    plt.xlabel("y")
    plt.ylabel("x")
    plt.tight_layout()
    plt.show()

# %%
plot_lattice("data/ising_J1.000_h1.000_T100.000_Lx300_Ly300_MC0.dat")
plot_lattice("data/ising_J1.000_h1.000_T100.000_Lx300_Ly300_MC1000000.dat")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot_lattice("data/ising_J1.000_h1.000_T100.000_Lx300_Ly300_MC0.dat")
#       2 plot_lattice("data/ising_J1.000_h1.000_T100.000_Lx300_Ly300_MC1000000.dat")
#
# Cell In[3], line 2, in plot_lattice(filename)
#       1 def plot_lattice(filename):
# ----> 2     lattice = np.loadtxt(filename)
#       4     plt.figure(figsize=(6, 6))
#       5     plt.imshow(lattice,
#       6                cmap="cool",
#       7                origin="lower",
#       8                vmin=-1,
#       9                vmax=1)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1395, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1392 if isinstance(delimiter, bytes):
#    1393     delimiter = delimiter.decode('latin1')
# -> 1395 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1396             converters=converters, skiplines=skiprows, usecols=usecols,
#    1397             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1398             max_rows=max_rows, quote=quotechar)
#    1400 return arr
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1022, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1020     fname = os.fspath(fname)
#    1021 if isinstance(fname, str):
# -> 1022     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1023     if encoding is None:
#    1024         encoding = getattr(fh, 'encoding', 'latin1')
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/numpy/lib/_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)    188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/numpy/lib/_datasource.py:529, in DataSource.open(self, path, mode, encoding, newline)
#     526     return _file_openers[ext](found, mode=mode,
#     527                               encoding=encoding, newline=newline)
#     528 else:
# --> 529     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: data/ising_J1.000_h1.000_T100.000_Lx300_Ly300_MC0.dat not found.

# %% [markdown]
# # Data Analysi

# %%
import pandas as pd

# %%
folder = "results"
fname = "ising_results_20260131_110358.csv"

df = pd.read_csv(folder + "/"+ fname)
print(df.head())
# Out:
#   backend    L init_type    J    h    T  n_steps    E  e_density      m  \
# 0   cpu_1  128    all_up  0.0  0.0  0.5  1000000  0.0        0.0 -168.0
# 1   cpu_1  128    all_up  0.0  0.0  0.5  1000000  0.0        0.0   -8.0
# 2   cpu_1  128    all_up  0.0  0.0  0.5  1000000  0.0        0.0 -136.0
# 3   cpu_1  128    all_up  0.0  0.0  0.5  1000000  0.0        0.0  -48.0
# 4   cpu_1  128    all_up  0.0  0.0  0.5  1000000  0.0        0.0  -24.0
#
#    m_density  init_time   mh_time  mh_time_per_step
# 0  -0.010254   0.000091  0.214052      2.140520e-07
# 1  -0.000488   0.000023  0.218969      2.189690e-07
# 2  -0.008301   0.000023  0.214190      2.141900e-07
# 3  -0.002930   0.000022  0.214172      2.141720e-07
# 4  -0.001465   0.000022  0.214190      2.141900e-07
